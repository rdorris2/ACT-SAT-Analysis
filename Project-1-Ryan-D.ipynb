# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# The number of high school students taking the SAT is significantly lower than students taking the ACT. How do we increase the future participation rate for SAT?

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
#  - Read in ACT & SAT CSV files to dataframes
#  - Converted numerical columns to float data types
#  - Renamed columns to reflect the data
#  - Dropped unnecessary columns
#  - Merged clean ACT & SAT dataframes
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
#  - Created ACT & SAT dataframes from CSV
#  - Changed numerical columns to float data types
#  - Renamed columns to reflect the data
#  - Removed unnecessary columns
#  - Combined clean SAT & ACT dataframes
#  - Merged clean 2017 & 2018 dataframes
#  - Saved final dataframe to CSV
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
#  -
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Import Numpy, Pandas, Seasborn, Pyplot, and Stats libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from pprint import pprint

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
# read and assign 2017 SAT and ACT csv files to pandas df
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
# shows the first 10 rows for SAT dataframe
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
# shows the first 10 rows for ACT dataframe
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: The two tables show the first 10 rows of the average ACT and SAT scores by states.I noticed that the national average row was included at the top of ACT table and missing in the SAT table. Since the national average is not included, the tables asynchronous and staggered. In the ACT table, the National row is index at 0 while the ACT table has Alabama row indexed at 0. I also noticed, states that have low SAT participation had higher ACT participation and vice versa. Alabama, Arkansas, and Colorado all have less than 12% participation in SAT's, but 100% participation in ACT's. This makes me assume that in those states, the ACT's are mandatory and the preferred test over SAT's. Its a similar phenomenon for the SAT table and this time its Connecticut, Deleware and District of Columbia with 100% participarion in SAT and below 33% particpation in ACT. First 4 states in ACT table had lower composite scores compared to other states and the national average. The highest composite score was 25.2 for Connecticut with the second lowest participation rate. I saw a trend for states that had lower participation rate in a test had higher scores. This makes sense because in those states those tests are not mandatory so the students who take that test are more serious.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Overall the data looks complete except for 1 thing. That is in the ACT table theres a row for the National data and the SAT is missing a National row.

# %%
# shows info about SAT dataframe
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# shows info about ACT dataframe
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
# - SAT highest composite score is 1600
# - ACT highest composite score is 36

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# checks for any null values in SAT dataframe
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
# checks for any null values in ACT dataframe
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
# prints SAT dataframe data types
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# prints ACT dataframe data types
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: Participation shows up as an object for ACT and SAT. Also Composite shows up as an object for ACT. Participation column and composite column need to be floats

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# .rstrip takes out the '%' from Participation column and .astype converts column to float
sat_2017['Participation'] = sat_2017['Participation'].str.rstrip('%').astype('float') / 100.0 
act_2017['Participation'] = act_2017['Participation'].str.rstrip('%').astype('float') / 100.0  

# check first 5 rows for SAT dataframe
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# replace the 20.2x value with 20.2 and inplace=True saves the changes
act_2017.Composite.replace(['20.2x'], [20.2], inplace=True)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# convert Composite column into a float 
act_2017.Composite = pd.DataFrame((act_2017.Composite), dtype='float')

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
# shows that the Composite column is a float now
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
# rename SAT columns to reflect the data
sat_2017.columns = ['state','participation_sat_17','read_write_sat_17','math_sat_17','total_sat_17']

# %%
# display re-named SAT columns
sat_2017.columns
# Out:
# Index(['state', 'participation_sat_17', 'read_write_sat_17', 'math_sat_17',
#        'total_sat_17'],
#       dtype='object')

# %%
# rename ACT columns to reflect the data
act_2017.columns = ['state','participation_act_17','english_act_17','math_act_17',
                    'reading_act_17','science_act_17','composite_act_17']

# %%
#diplay re-named ACT columns
act_2017.columns
# Out:
# Index(['state', 'participation_act_17', 'english_act_17', 'math_act_17',
#        'reading_act_17', 'science_act_17', 'composite_act_17'],
#       dtype='object')

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %%
# create SAT Dictionaries using the zip command and list comprehension
Sat_Read_And_Write_17 = {k:v for (k,v) in zip(sat_2017['state'],sat_2017['read_write_sat_17'])}
Sat_Math_17 = {k:v for (k,v) in zip(sat_2017['state'], sat_2017['math_sat_17'])}
Sat_Total_17 = {k:v for (k,v) in zip(sat_2017['state'], sat_2017['total_sat_17'])}

# %%
# create ACT Dictionaries using the zip command and list comprehesnion
Act_English_17 = {k:v for (k,v) in zip(act_2017['state'], act_2017['english_act_17'])}
Act_Math_17 = {k:v for (k,v) in zip(act_2017['state'], act_2017['math_act_17'])}
Act_Reading_17 = {k:v for (k,v) in zip(act_2017['state'], act_2017['reading_act_17'])}
Act_Science_17 = {k:v for (k,v) in zip(act_2017['state'], act_2017['science_act_17'])}
Act_Composite_17 = {k:v for (k,v) in zip(act_2017['state'], act_2017['composite_act_17'])}

# %%
# set each test to dictionary
sat_dict = sat_2017.to_dict(orient='list')
act_dict = act_2017.to_dict(orient='list')

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# remove the unnecessary National row from ACT dataframe and save to act_2017
act_2017 = act_2017.tail(51)

# show first 5 rows of act_2017
act_2017.head()
# Out:
#         state  participation_act_17  english_act_17  math_act_17  \
# 1     Alabama                  1.00            18.9         18.4
# 2      Alaska                  0.65            18.7         19.8
# 3     Arizona                  0.62            18.6         19.8
# 4    Arkansas                  1.00            18.9         19.0
# 5  California                  0.31            22.5         22.7
#
#    reading_act_17  science_act_17  composite_act_17
# 1            19.7            19.4              19.2
# 2            20.4            19.9              19.8
# 3            20.1            19.8              19.7
# 4            19.7            19.5              19.4
# 5            23.1            22.2              22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# merge SAT and ACT dataframes on 'state' column and assign to clean_table variable
clean_table = pd.merge(sat_2017, act_2017, how='inner', on='state')

# show data types of clean_table variable
clean_table.dtypes
# Out:
# state                    object
# participation_sat_17    float64
# read_write_sat_17         int64
# math_sat_17               int64
# total_sat_17              int64
# participation_act_17    float64
# english_act_17          float64
# math_act_17             float64
# reading_act_17          float64
# science_act_17          float64
# composite_act_17        float64
# dtype: object

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
# save clean_table dataframe as csv to a relative path
clean_table.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# read and assign 2018 SAT and ACT csv files to pandas df
sat_2018 = pd.read_csv('../data/East_Coast_Data_Entry - SAT 2018.csv')
act_2018 = pd.read_csv('../data/East_Coast_Data_Entry - ACT 2018.csv')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# Participation column shows up as an object and needs to be converted to a float
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# Participation column shows up as an object and needs to be converted to a float
act_2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
# .rstrip removes '%', .astype converts to float and multiply by 100, save chnages  
sat_2018['Participation'] = sat_2018['Participation'].str.rstrip('%').astype('float') / 100.0  
act_2018['Participation'] = act_2018['Participation'].str.rstrip('%').astype('float') / 100.0

# %%
# shows Participation column as a float
sat_2018.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
act_2018.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
# rename SAT columns so they are easily identifiable
sat_2018.columns = ['state','participation_sat_18','read_write_sat_18','math_sat_18','total_sat_18']

# %%
# rename ACT columns so they are easily identifiable
act_2018.columns = ['state','participation_act_18','composite_act_18']

# %%
# create SAT Dictionaries using the zip command and list comprehension
sat_read_and_write_18 = {k:v for (k,v) in zip(sat_2018['state'],sat_2018['read_write_sat_18'])}
sat_math_18 = {k:v for (k,v) in zip(sat_2018['state'], sat_2018['math_sat_18'])}
sat_total_18 = {k:v for (k,v) in zip(sat_2018['state'], sat_2018['total_sat_18'])}

# %%
# create ACT Dictionaries using the zip command and list comprehesnion
act_composite_18 = {k:v for (k,v) in zip(act_2018['state'], act_2018['composite_act_18'])}

# %%
sat_18_dict = sat_2018.to_dict(orient='list')
act_18_dict = act_2018.to_dict(orient='list')

# %%
# merge the 2018 SAT and ACT dataframes on state and save to merged_data_18
merge_data_18 = pd.merge(sat_2018, act_2018, how='inner', on='state')

# remove National Row and save to clean_table_18
clean_table_18 = merge_data_18.head(50)

# %%
# merge combined 2017 dataframess with combined 2018 dataframes and save to final_table
final_table = pd.merge(clean_table,clean_table_18, how='inner', on='state')

# show first 5 rows of final_table 
final_table.head()
# Out:
#         state  participation_sat_17  read_write_sat_17  math_sat_17  \
# 0     Alabama                  0.05                593          572
# 1      Alaska                  0.38                547          533
# 2     Arizona                  0.30                563          553
# 3    Arkansas                  0.03                614          594
# 4  California                  0.53                531          524
#
#    total_sat_17  participation_act_17  english_act_17  math_act_17  \
# 0          1165                  1.00            18.9         18.4
# 1          1080                  0.65            18.7         19.8
# 2          1116                  0.62            18.6         19.8
# 3          1208                  1.00            18.9         19.0
# 4          1055                  0.31            22.5         22.7
#
#    reading_act_17  science_act_17  composite_act_17  participation_sat_18  \
# 0            19.7            19.4              19.2                  0.06
# ...

# %%
# save final_table dataframe as csv to a relative path
final_table.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
# use describe method to display quick statistics for each column
final_table.describe().T
# Out:
#                       count       mean        std     min        25%  \
# participation_sat_17   50.0     0.3860   0.345602    0.02     0.0400
# read_write_sat_17      50.0   570.8600  44.385146  503.00   535.2500
# math_sat_17            50.0   549.2200  84.998269   52.00   523.2500
# total_sat_17           50.0  1129.6200  89.913085  996.00  1057.0000
# participation_act_17   50.0     0.6592   0.321107    0.08     0.3100
# english_act_17         50.0    20.8620   2.324307   16.30    19.0000
# math_act_17            50.0    21.1360   1.973990   18.00    19.4000
# reading_act_17         50.0    21.9560   2.046317   18.10    20.4250
# science_act_17         50.0    20.9920   3.195139    2.30    19.9000
# composite_act_17       50.0    21.4660   2.004241   17.80    19.8000
# participation_sat_18   50.0     0.4430   0.370704    0.02     0.0425
# read_write_sat_18      50.0   569.1200  44.619772  505.00   536.2500
# math_sat_18            50.0   560.0200  48.668177  486.00   525.0000
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
# create stan_dev function that takes std of each column and displays to a list 
def stan_dev(final_table):
    return [final_table[col].std() for col in
           final_table.select_dtypes(include = ['float','int64']).columns.tolist()]

# %%
# ran stan_dev function on final_table and saved to std variable
std = stan_dev(final_table)

# show std output
std
# Out:
# [0.3456021069474703,
#  44.38514643988229,
#  84.99826888993513,
#  89.91308501626924,
#  0.3211067595370863,
#  2.3243072261714137,
#  1.9739900543553606,
#  2.0463167508716626,
#  3.1951391653125665,
#  2.0042414209544193,
#  0.37070396352268553,
#  44.61977231713149,
#  48.668176754131935,
#  92.94413727105773,
#  0.3411411820968688,
#  2.1113116147773816]

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
df_data = {}
for i, j in zip(final_table.columns, ['Total Std'] + stan_dev(final_table)):
    df_data[i] = j
print(df_data)
# Out:
# {'state': 'Total Std', 'participation_sat_17': 0.3456021069474703, 'read_write_sat_17': 44.38514643988229, 'math_sat_17': 84.99826888993513, 'total_sat_17': 89.91308501626924, 'participation_act_17': 0.3211067595370863, 'english_act_17': 2.3243072261714137, 'math_act_17': 1.9739900543553606, 'reading_act_17': 2.0463167508716626, 'science_act_17': 3.1951391653125665, 'composite_act_17': 2.0042414209544193, 'participation_sat_18': 0.37070396352268553, 'read_write_sat_18': 44.61977231713149, 'math_sat_18': 48.668176754131935, 'total_sat_18': 92.94413727105773, 'participation_act_18': 0.3411411820968688, 'composite_act_18': 2.1113116147773816}

# %%
# create a dataframe to be appended at the bottom
pd.DataFrame(data=df_data, index=[final_table.index[-1]])

# append the STD total row to the original df and assign to new df ('sd')
sd = final_table.append(pd.DataFrame(data=df_data, index=[final_table.index[-1]]))

# columns of the std df in the proper order
sd = sd[final_table.columns.tolist()]

#  check that changes where made
sd.tail(3)
# Out:
#         state  participation_sat_17  read_write_sat_17  math_sat_17  \
# 48  Wisconsin              0.030000         642.000000   649.000000
# 49    Wyoming              0.030000         626.000000   604.000000
# 49  Total Std              0.345602          44.385146    84.998269
#
#     total_sat_17  participation_act_17  english_act_17  math_act_17  \
# 48   1291.000000              1.000000       19.700000     20.40000
# 49   1230.000000              1.000000       19.400000     19.80000
# 49     89.913085              0.321107        2.324307      1.97399
#
#     reading_act_17  science_act_17  composite_act_17  participation_sat_18  \
# 48       20.600000       20.900000         20.500000              0.030000
# 49       20.800000       20.600000         20.200000              0.030000
# 49        2.046317        3.195139          2.004241              0.370704
#
#     read_write_sat_18  math_sat_18  total_sat_18  participation_act_18  \
# ...

# %%
np.std(final_table)
# Out:
# participation_sat_17     0.342129
# read_write_sat_17       43.939053
# math_sat_17             84.143993
# total_sat_17            89.009413
# participation_act_17     0.317879
# english_act_17           2.300947
# math_act_17              1.954150
# reading_act_17           2.025750
# science_act_17           3.163026
# composite_act_17         1.984098
# participation_sat_18     0.366978
# read_write_sat_18       44.171321
# math_sat_18             48.179037
# total_sat_18            92.010002
# participation_act_18     0.337713
# composite_act_18         2.090092
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer: My manually calculated standard deviation match up with the output of pandas describe. My manually calculated std is slightly off by 1 point or decimals.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# sort values based on column and in ascending order
final_table.sort_values('participation_sat_17', ascending=True)
# Out:
#              state  participation_sat_17  read_write_sat_17  math_sat_17  \
# 33    North Dakota                  0.02                635          621
# 23     Mississippi                  0.02                634          607
# 14            Iowa                  0.02                641          635
# 24        Missouri                  0.03                640          631
# 43            Utah                  0.03                624          614
# 40    South Dakota                  0.03                612          603
# 26        Nebraska                  0.03                629          625
# 48       Wisconsin                  0.03                642          649
# 22       Minnesota                  0.03                644          651
# 49         Wyoming                  0.03                626          604
# 3         Arkansas                  0.03                614          594
# 15          Kansas                  0.04                632          628
# ...

# %%
# used boolean to show column has values greated or equal to 50%
final_table[(final_table)['participation_sat_17'] >= 0.50]
# Out:
#              state  participation_sat_17  read_write_sat_17  math_sat_17  \
# 4       California                  0.53                531          524
# 6      Connecticut                  1.00                530          512
# 7         Delaware                  1.00                503          492
# 8          Florida                  0.83                520          497
# 9          Georgia                  0.61                535          515
# 10          Hawaii                  0.55                544          541
# 11           Idaho                  0.93                513          493
# 13         Indiana                  0.63                542          532
# 18           Maine                  0.95                513          499
# 19        Maryland                  0.69                536           52
# 20   Massachusetts                  0.76                555          551
# 21        Michigan                  1.00                509          495
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# visual correlations between all numerical features in final_table
sns.heatmap(final_table.corr());

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
# def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
#     nrows = int(np.ceil(len(list_of_columns)/2) # Makes sure you have enough rows
#     fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
#     ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
#     for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
#         ax[i].hist(dataframe[column]) # feel free to add more settings
#         # Set titles, labels, etc here faor each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Draws histograms of the SAT and ACT participation variables
plt.figure(1)
n, bins, patches = plt.hist(final_table['participation_sat_17'], 10, facecolor='red')
plt.xlabel('Participation Rate')
plt.title('SAT Participation Rate 2017')
plt.show()

plt.figure(2)
n, bins, patches = plt.hist(final_table['participation_act_17'], 10, facecolor='blue')
plt.xlabel('Participation Rate')
plt.title('ACT Participation Rate 2017')
plt.show()

# %%
# Draws histograms of the SAT and ACT participation variables
plt.figure(1)
n, bins, patches = plt.hist(final_table['participation_sat_18'], 10, facecolor='red')
plt.xlabel('Participation Rate')
plt.title('SAT Participation Rate 2018')
plt.show()

plt.figure(2)
n, bins, patches = plt.hist(final_table['participation_act_18'], 10, facecolor='blue')
plt.xlabel('Participation Rate')
plt.title('ACT Participation Rate 2018')
plt.show()

# %%
final_table.columns
# Out:
# Index(['state', 'participation_sat_17', 'read_write_sat_17', 'math_sat_17',
#        'total_sat_17', 'participation_act_17', 'english_act_17', 'math_act_17',
#        'reading_act_17', 'science_act_17', 'composite_act_17',
#        'participation_sat_18', 'read_write_sat_18', 'math_sat_18',
#        'total_sat_18', 'participation_act_18', 'composite_act_18'],
#       dtype='object')

# %%
# Cleaning up outliers from the SAT Math and ACT Science columns.  Both seem to have at least one point that is
# significantly lower than the other scores.

final_sat_math = final_table[(final_table)['math_sat_17'] >= 300]
final_act_science = final_table[(final_table)['science_act_17'] >= 15]

# %%
# plots the distribution of math and science scores

plt.figure(1)
n, bins, patches = plt.hist(final_sat_math['math_sat_17'], 10, facecolor='green')
plt.xlabel('Math Score')
plt.ylabel('Probability')
plt.title('SAT 2017 Math')

plt.show()

plt.figure(2)
n, bins, patches = plt.hist(final_table['math_act_17'], 10, facecolor='green')
plt.xlabel('Math Score')
plt.ylabel('Probability')
plt.title('ACT 2017 Math')

plt.show()

plt.figure(3)
n, bins, patches = plt.hist(final_act_science['science_act_17'], 10, facecolor='green')
plt.xlabel('Science Score')
plt.ylabel('Probability')
plt.title('ACT 2017 Science')

plt.show()

# %%
final_table.columns
# Out:
# Index(['state', 'participation_sat_17', 'read_write_sat_17', 'math_sat_17',
#        'total_sat_17', 'participation_act_17', 'english_act_17', 'math_act_17',
#        'reading_act_17', 'science_act_17', 'composite_act_17',
#        'participation_sat_18', 'read_write_sat_18', 'math_sat_18',
#        'total_sat_18', 'participation_act_18', 'composite_act_18'],
#       dtype='object')

# %%
plt.figure(1)
n, bins, patches = plt.hist(final_table['read_write_sat_17'], 10, facecolor='yellow')
plt.xlabel('Reading and Writing Score')
plt.ylabel('Probability')
plt.title('SAT Reading and Writing')

plt.show()

plt.figure(2)
n, bins, patches = plt.hist(final_table['english_act_17'], 10, facecolor='yellow')
plt.xlabel('English Score')
plt.ylabel('Probability')
plt.title('ACT English')

plt.show()

plt.figure(3)
n, bins, patches = plt.hist(final_table['reading_act_17'], 10, facecolor='yellow')
plt.xlabel('Reading Score')
plt.ylabel('Probability')
plt.title('ACT Reading')

plt.show()

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# creates many scatter plots for final_table
g = sns.pairplot(final_table, palette='Greens')
plt.show();

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# clean data by removing outliers from SAT math and ACT science columns.  
clean_sat_math = clean_table[(clean_table)['math_sat_17'] >= 300]
clean_act_science = clean_table[(clean_table)['science_act_17'] >= 15]

# %%
# use cleaner data set that filters out outliers in SAT Math and ACT Science to create boxplots
sat_clean_boxplots = [clean_sat_math['math_sat_17'], clean_table['read_write_sat_17']]
sat_labels = ('Math', 'Reading and Writing')
plt.figure(1)
plt.boxplot(sat_clean_boxplots, labels = sat_labels)
plt.title('SAT Scores')

act_clean_boxplots = [clean_table['english_act_17'], clean_table['reading_act_17'], 
                      clean_table['math_act_17'], 
                      clean_act_science['science_act_17']]
act_labels = ('English', 'Reading', 'Math', 'Science')
plt.figure(2)
plt.boxplot(act_clean_boxplots, labels = act_labels)
plt.title('ACT Scores')

participation_boxplots = [clean_table['participation_sat_17'], 
                          clean_table['participation_act_17']]

part_labels = ('SAT', 'ACT')
plt.figure(3)
plt.boxplot(participation_boxplots, labels = part_labels)
plt.title('Participation Rates');

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
#
# - Symmetric distributions are when mean is equal to mode is equal to median.
#  - ACT science is close to a normal distribution (Mode = 20.9, Median = 21.3, Mean = 21.4)
# - Negative skew is when the mean is less than the median which is less than the mode.
#  - ACT participation rate i negatively skewed; participation is high (Mean .653, Median = .69, Mode = 1)
# - Positive skew is when the mode is less than the median which is less than the mean.
#  - SAT participation rate is positively skewed; participation is low (Mode = .03, Median = .38, Mean = .398)
#  - Both the SAT and ACT math scores are positively skewed (Mode < Median < Mean)
#  - SAT Read & Write, ACT English, and ACT Reading are positvely skewed

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: We only observed a normal distribution in ACT science column but all the other columns are either positively or negatively skewed.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# Most of the relationships between variables are inherently straightforward. For example, the SAAT MAth and SAT Reading and Writing hhave a linear relatioship. This is because since students who have high Math score will tend to have a higher REading and Writing score. The scatter plot makes taht visually apparent. This is also true for the ACT data, where eah score variable have a positive linear relationship..

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: This doesnt make much sense because the tests are looked at differenly from state to state. So some states might require ACT test for college while others requires SATs.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
#  It would not be appropriate to generate correlation between ACT and SAT Math scores since the score is significantly different between the two tests.  SAT Math scores range from 200 to 800 while ACT Math scores range from 1-36.  There would not be a good way to correlate to two based on how the results are reported. The scatterplot for ACT Math vs SAT Math also shows insignficant correlation between the two.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:
# Two sample t-test is the best hypothesis test to do

# H0 (null hypothesis):         μ_SAT = μ_ACT   
# HA:(alternative hypothesis):  μ_SAT ≠ μ_ACT

stats.ttest_ind(final_table['participation_sat_17'], final_table['participation_act_17'])

# p is 8.69e^-05 while alpha is 0.05
# Because p is less than alpha, we reject the null hypothesis and conclude that the alternative hypothesis is true.
# Out:
# Ttest_indResult(statistic=-4.094977684649379, pvalue=8.69139250100431e-05)

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Based on my exploration of data, I got a sense of the how each state looks at ACT and SAT tests. Most relationships between variables are pretty straightforward. For example, the SAT Math and SAT Reading and Writing hhave a linear relatioship. This is because since students who have high Math score will tend to have a higher Reading and Writing score. I would suggest the College Board to give free preparation tests during school hours, make them free and create a reward system for completing prep tests.
